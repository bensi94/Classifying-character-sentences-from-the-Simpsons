# %%
# Imports and read the simpson data in
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import csv
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
import datetime

# %%
simpsons_df = pd.read_csv('simpsons_script_lines.csv', error_bad_lines=False, warn_bad_lines=False, low_memory=False, index_col='id')

def dict_from_csv(csv_file_name):
    with open(csv_file_name, mode='r') as infile:
        next(infile)
        reader = csv.reader(infile)
        return_dict = {int(rows[0]):rows[1] for rows in reader}
        return return_dict

character_dict = dict_from_csv('simpsons_characters.csv')
location_dict = dict_from_csv('simpsons_locations.csv')

# %%
# Clear up the data
# We need to have value in character_id, location_id, and normalized_text so we drop nan rows
simpsons_df = simpsons_df.dropna(subset=['character_id', 'location_id', 'normalized_text'])
# In number, timestamp_in_ms, raw_text, and speaking_line we have no extra information so we drop those columns
simpsons_df = simpsons_df.drop(['number', 'timestamp_in_ms', 'raw_text', 'speaking_line'], axis=1)
# Change numeric values to numeric
simpsons_df['character_id'] = pd.to_numeric(simpsons_df['character_id'])
simpsons_df['location_id'] = pd.to_numeric(simpsons_df['location_id'], downcast='integer')
simpsons_df['word_count'] = pd.to_numeric(simpsons_df['word_count'], downcast='integer')

# %%
# Count how many lines each character has
character_line_counts = Counter(simpsons_df['character_id']).most_common()

most_common_characters = []

# If character has fewer than 200 lines we will not inlcude that character
for character in character_line_counts:
    if character[1] >= 200:
        most_common_characters.append(character[0])
simpsons_df = simpsons_df[simpsons_df['character_id'].isin(most_common_characters)]

temp_dict = {character: character_dict[character] for character in most_common_characters}
character_dict = temp_dict

# %%
# Count how many lines are at location
locations = Counter(simpsons_df['location_id']).most_common()

most_common_locations = []

# If there are fewer than 100 lines at location we do not use that location
for location in locations:
    if location[1] >= 100:
        most_common_locations.append(location[0])
#simpsons_df = simpsons_df[simpsons_df['location_id'].isin(most_common_locations)]

temp_dict = {location: location_dict[location] for location in most_common_locations}
location_dict = temp_dict

# %%
# Here we count how many sentences each character has 
value_counts = simpsons_df['character_id'].value_counts()
# Plot a bar plot with the counts
count_plot = value_counts.plot(kind='bar', figsize=(15,8))
# Change the ID of thoose characters to names
count_plot.set_xticklabels([character_dict[i] for i in value_counts.keys()])
plt.show()

# %%
# GOTT FYRIR SKÝRSLU: NOTUM TfidfVectorizer útaf því það er nákvæmara en CountVectorizer
# CountVectorizer telur bara frequncy á orðunum en TfidfVectorizer gerir mun á hversu frequent orð eru
# Nánara info hér: https://www.quora.com/What-is-the-difference-between-TfidfVectorizer-and-CountVectorizer-1

# Min_df is the minimum amount of toke frequency to be kept
# stop_words is to skip words like 'a, the' etc.
# sublinear_tf is used so we can do sublinear tf scaling (replace tf with 1+log(tf))
# Norm L2 is L2-normalization to minimize single outliers
# ngram_range is 1,3 so we select tokens of wordsizes: 1, 2 and 3

tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, stop_words='english', norm='l2', ngram_range=(1,3))

features = tfidf.fit_transform(simpsons_df.normalized_text)
labels = simpsons_df.character_id
features.shape
# Out:
# (99670, 16239)

# %%
most_popular_df = pd.DataFrame()
# Get the 5 most popular tokens
token_count = 5
tokenNames = ['Token ' + str(i) for i in range(1, token_count+1)]

for character_id in character_dict:
    features_chi2 = chi2(features, labels == character_id)
    # Here the we sort the most common features of each character in order
    # features_chi2[0] stands for chi statistics of each character
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    # Split features in single or two word grams
    unigrams = [word for word in feature_names if len(word.split(' ')) == 1]
    biggrams = [words for words in feature_names if len(words.split(' ')) == 2]
    
    # If we don't have enough tokens for any charater we fill it with nan 
    if len(unigrams) < token_count:
        for i in range(len(unigrams), token_count+1):
            unigrams.append(np.nan)
    if len(biggrams) < token_count:
        for i in range(len(biggrams), token_count+1):
            biggrams.append(np.nan)
    
    # Append most common single word tokens to the dataframe
    character = "UNI: " + character_dict[character_id]
    most_popular_df = most_popular_df.append(
        pd.DataFrame([unigrams[-token_count:]], index=[character], columns=tokenNames))
    # Append the most common two word tokens to the dataframe
    character = "BIG: " + character_dict[character_id]                                          
    most_popular_df = most_popular_df.append(pd.DataFrame([biggrams[-token_count:]], index=[character], columns=tokenNames))
                                               
most_popular_df.head(10)
# Out:
#                               Token 1        Token 2      Token 3  \
# UNI: Homer Simpson                dad          homer          hoo
# BIG: Homer Simpson        marge youre        heh heh     marge im
# UNI: Marge Simpson                dad            hey      husband
# BIG: Marge Simpson         homer stop     homer dont     homie im
# UNI: Bart Simpson                cool        carumba     milhouse
# BIG: Bart Simpson             im bart    aye carumba      hey dad
# UNI: Lisa Simpson               marge          homer         bart
# BIG: Lisa Simpson           dad youre         oh dad     dad dont
# UNI: C. Montgomery Burns       hounds        simpson          bah
# BIG: C. Montgomery Burns     ahoy hoy  look smithers  oh smithers
#
#                               Token 4     Token 5
# UNI: Homer Simpson                woo       marge
# BIG: Homer Simpson           oh marge     woo hoo
# UNI: Marge Simpson              homer       homie
# BIG: Marge Simpson           oh homer    oh homie
# UNI: Bart Simpson                 dad         lis
# BIG: Bart Simpson             hey lis  ay carumba
# UNI: Lisa Simpson                 mom         dad
# BIG: Lisa Simpson             mom dad   dad thats
# UNI: C. Montgomery Burns    excellent    smithers
# BIG: C. Montgomery Burns  smithers im  simpson eh

# %%
x_train, x_test, y_train, y_test = train_test_split(simpsons_df[['normalized_text', 'location_id', 'episode_id', 'word_count']], simpsons_df['character_id'], random_state=42, test_size=0.2)
x_train_vec = tfidf.fit_transform(x_train['normalized_text'])
x_test_vec = tfidf.transform(x_test['normalized_text'])
x_train_others = x_train[['location_id', 'episode_id', 'word_count']]
x_test_other = x_test[['location_id', 'episode_id', 'word_count']]
# Out:
# <79736x13124 sparse matrix of type '<class 'numpy.float64'>'
# 	with 411790 stored elements in Compressed Sparse Row format>

# %%
def print_cnf_matrix(test, prediction):
    cnf_matrix = confusion_matrix(test, prediction)
    plt.subplots(figsize=(15,8))
    sns.heatmap(cnf_matrix, annot=False, fmt='d', vmax=100)
    plt.show()

# %%
clf = DecisionTreeClassifier(random_state=42)
clf.fit(x_train_others, y_train)

prediction = clf.predict(x_test_other)
print("The accuracy is:", accuracy_score(y_test, prediction))
print_cnf_matrix(y_test, prediction)
# Out:
# The accuracy is: 0.3302899568576302

# %%
svc = LinearSVC(C=0.09526315789473684, multi_class='ovr')

svc.fit(x_train_vec, y_train)

test_prediction = svc.predict(x_test_vec)
print("The accuracy is:", accuracy_score(y_test, test_prediction))
print_cnf_matrix(y_test, test_prediction)
test_prediction
# Out:
# The accuracy is: 0.368566268686666
# array([2, 8, 2, ..., 1, 8, 2])

# %%
simpsons_df
# Out:
#       episode_id  character_id  location_id       raw_character_text  \
# id
# 9550          32             9            3             Lisa Simpson
# 9552          32             9            3             Lisa Simpson
# 9553          32            40            3  Edna Krabappel-Flanders
# 9554          32            38            3            Martin Prince
# 9555          32            40            3  Edna Krabappel-Flanders
# 9556          32             8            3             Bart Simpson
# 9558          32             9          374             Lisa Simpson
# 9560          32             9          374             Lisa Simpson
# 9562          32             9          374             Lisa Simpson
# 9564          32             9          374             Lisa Simpson
# 9566          32             8            3             Bart Simpson
# 9567          32           101            3             Nelson Muntz
# 9568          32             8            3             Bart Simpson
# 9570          32             8            3             Bart Simpson
# 9571          32            25            3      Milhouse Van Houten
# 9572          32             8            3             Bart Simpson
# 9573          32             8            3             Bart Simpson
# 9574          32            25            3      Milhouse Van Houten
# 9575          32             8            3             Bart Simpson
# 9578          32             8            3             Bart Simpson
# 9579          32            40            3  Edna Krabappel-Flanders
# 9580          32             8            3             Bart Simpson
# 9581          32            40            3  Edna Krabappel-Flanders
# 9585          32             9          375             Lisa Simpson
# 9587          32             9          375             Lisa Simpson
# 9589          32             9          375             Lisa Simpson
# 9591          32             9          375             Lisa Simpson
# 9593          32             9          375             Lisa Simpson
# 9595          32             9          375             Lisa Simpson
# 9597          32             9          375             Lisa Simpson
# ...          ...           ...          ...                      ...
# 9506          32             9          372             Lisa Simpson
# 9508          32             9          372             Lisa Simpson
# 9509          32             2          372            Homer Simpson
# 9510          32             9          372             Lisa Simpson
# 9512          32             2          372            Homer Simpson
# 9514          32             2          372            Homer Simpson
# 9516          32             2          372            Homer Simpson
# 9518          32             2          372            Homer Simpson
# 9520          32             2          372            Homer Simpson
# 9522          32             9          373             Lisa Simpson
# 9523          32             1          373            Marge Simpson
# 9524          32             9          373             Lisa Simpson
# 9525          32             1          373            Marge Simpson
# 9526          32             9          373             Lisa Simpson
# 9527          32             1          373            Marge Simpson
# 9528          32             9          373             Lisa Simpson
# 9529          32             1          373            Marge Simpson
# 9530          32             9          373             Lisa Simpson
# 9531          32             1          373            Marge Simpson
# 9532          32             9          373             Lisa Simpson
# 9533          32             1          373            Marge Simpson
# 9534          32             9          373             Lisa Simpson
# 9535          32             1          373            Marge Simpson
# 9536          32             9          373             Lisa Simpson
# 9537          32             1          373            Marge Simpson
# 9538          32             9          373             Lisa Simpson
# 9539          32             1          373            Marge Simpson
# 9540          32             9          373             Lisa Simpson
# 9542          32             9            3             Lisa Simpson
# 9547          32           119            3             Ralph Wiggum
#
#                        raw_location_text  \
# id
# 9550       Springfield Elementary School
# 9552       Springfield Elementary School
# 9553       Springfield Elementary School
# 9554       Springfield Elementary School
# 9555       Springfield Elementary School
# 9556       Springfield Elementary School
# 9558                  Apartment Building
# 9560                  Apartment Building
# 9562                  Apartment Building
# 9564                  Apartment Building
# 9566       Springfield Elementary School
# 9567       Springfield Elementary School
# 9568       Springfield Elementary School
# 9570       Springfield Elementary School
# 9571       Springfield Elementary School
# 9572       Springfield Elementary School
# 9573       Springfield Elementary School
# 9574       Springfield Elementary School
# 9575       Springfield Elementary School
# 9578       Springfield Elementary School
# 9579       Springfield Elementary School
# 9580       Springfield Elementary School
# 9581       Springfield Elementary School
# 9585                       Train Station
# 9587                       Train Station
# 9589                       Train Station
# 9591                       Train Station
# 9593                       Train Station
# 9595                       Train Station
# 9597                       Train Station
# ...                                  ...
# 9506                              Museum
# 9508                              Museum
# 9509                              Museum
# 9510                              Museum
# 9512                              Museum
# 9514                              Museum
# 9516                              Museum
# 9518                              Museum
# 9520                              Museum
# 9522  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9523  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9524  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9525  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9526  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9527  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9528  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9529  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9530  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9531  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9532  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9533  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9534  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9535  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9536  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9537  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9538  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9539  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9540  SIMPSON HOUSE - BASEMENT STAIRCASE
# 9542       Springfield Elementary School
# 9547       Springfield Elementary School
#
#                                            spoken_words  \
# id
# 9550                             Where's Mr. Bergstrom?
# 9552                         That life is worth living.
# 9553  The polls will be open from now until the end ...
# 9554        I don't think there's anything left to say.
# 9555                                              Bart?
# 9556                     Victory party under the slide!
# 9558                      Mr. Bergstrom! Mr. Bergstrom!
# 9560                Do you know where I could find him?
# 9562  The train, how like him... traditional, yet en...
# 9564                         I see he touched you, too.
# 9566                    Hey, thanks for your vote, man.
# 9567                 I didn't vote. Voting's for geeks.
# 9568  Well, you got that right. Thanks for your vote...
# 9570  Well, don't sweat it. Just so long as a couple...
# 9571                                             Uh oh.
# 9572                                             Lewis?
# 9573                          Somebody must have voted.
# 9574             What about you, Bart? Didn't you vote?
# 9575                                             Uh oh.
# 9578                                I demand a recount.
# 9579  One for Martin, two for Martin. Would you like...
# 9580                                                No.
# 9581  Well, I just want to make sure. One for Martin...
# 9585                 Mr. Bergstrom! Hey, Mr. Bergstrom!
# 9587                                 Hey, Lisa, indeed.
# 9589  Oh, I mean, were you just going to leave, just...
# 9591  You can't go! You're the best teacher I'll eve...
# 9593                                        Oh, please.
# 9595                                But I need you too.
# 9597  I, I understand. Mr. Bergstrom, I'm going to m...
# ...                                                 ...
# 9506                                               Wow!
# 9508                                       Ewww. Gross.
# 9509  Ohh, pretty creepy. Still, I'd rather have him...
# 9510                                           Oh Lord.
# 9512                                     She said that?
# 9514  But you can tell, right? She looks around and ...
# 9516        Well, if she's so wonderful, give her an A.
# 9518  Great. But don't tell her it was a favor to me...
# 9520                You are smooth. I'll give you that.
# 9522  He ruined the one chance I had of getting to k...
# 9523  Well... I'll tell you what. Why don't we invit...
# 9524  Oh, Mom, that's wonderful. Can I find out his ...
# 9525                                              Sure.
# 9526                           Can I wear your jewelry?
# 9527                                              Sure.
# 9528                         Can I get my ears pierced?
# 9529                                                No.
# 9530                           Can I dye my shoes pink?
# 9531                                               Yes.
# 9532                              Can I paint my nails?
# 9533                                                No.
# 9534                                  Can we have wine?
# 9535                                               Yes.
# 9536                                   Can I have wine?
# 9537                                                No.
# 9538                        Does Bart have to be there?
# 9539                                               Yes.
# 9540                            Can we do it this week?
# 9542  Mr. Bergstrom, we request the pleasure of your...
# 9547                     Does that mean you were crazy?
#
#                                         normalized_text  word_count
# id
# 9550                                wheres mr bergstrom           3
# 9552                          that life is worth living           5
# 9553  the polls will be open from now until the end ...          33
# 9554           i dont think theres anything left to say           8
# 9555                                               bart           1
# 9556                      victory party under the slide           5
# 9558                          mr bergstrom mr bergstrom           4
# 9560                 do you know where i could find him           8
# 9562  the train how like him traditional yet environ...           9
# 9564                           i see he touched you too           6
# 9566                       hey thanks for your vote man           6
# 9567                     i didnt vote votings for geeks           6
# 9568  well you got that right thanks for your vote g...          10
# 9570  well dont sweat it just so long as a couple of...          15
# 9571                                              uh oh           2
# 9572                                              lewis           1
# 9573                           somebody must have voted           4
# 9574                 what about you bart didnt you vote           7
# 9575                                              uh oh           2
# 9578                                 i demand a recount           4
# 9579  one for martin two for martin would you like a...          11
# 9580                                                 no           1
# 9581  well i just want to make sure one for martin t...          13
# 9585                      mr bergstrom hey mr bergstrom           5
# 9587                                    hey lisa indeed           3
# 9589  oh i mean were you just going to leave just li...          12
# 9591   you cant go youre the best teacher ill ever have          10
# 9593                                          oh please           2
# 9595                                 but i need you too           5
# 9597   i i understand mr bergstrom im going to miss you          10
# ...                                                 ...         ...
# 9506                                                wow           1
# 9508                                         ewww gross           2
# 9509  ohh pretty creepy still id rather have him cha...          15
# 9510                                            oh lord           2
# 9512                                      she said that           3
# 9514  but you can tell right she looks around and se...          40
# 9516            well if shes so wonderful give her an a           9
# 9518  great but dont tell her it was a favor to me t...          16
# 9520                   you are smooth ill give you that           7
# 9522  he ruined the one chance i had of getting to k...          16
# 9523  well ill tell you what why dont we invite mr b...          13
# 9524  oh mom thats wonderful can i find out his favo...          16
# 9525                                               sure           1
# 9526                            can i wear your jewelry           5
# 9527                                               sure           1
# 9528                          can i get my ears pierced           6
# 9529                                                 no           1
# 9530                            can i dye my shoes pink           6
# 9531                                                yes           1
# 9532                               can i paint my nails           5
# 9533                                                 no           1
# 9534                                   can we have wine           4
# 9535                                                yes           1
# 9536                                    can i have wine           4
# 9537                                                 no           1
# 9538                         does bart have to be there           6
# 9539                                                yes           1
# 9540                             can we do it this week           6
# 9542  mr bergstrom we request the pleasure of your c...          33
# 9547                      does that mean you were crazy           6
#
# [99670 rows x 8 columns]

# %%
mnb = MultinomialNB(alpha=0.33684210526315794)
mnb.fit(x_train_vec, y_train)
mnb.predict_proba(x_test_vec)



from sklearn.preprocessing import LabelEncoder

classifiers = [(mnb, MultinomialNB(alpha=0.33684210526315794)),(clf, DecisionTreeClassifier(random_state=42))]
x_list = [x_test_vec, x_test_other]

pred1 = np.asarray([current_clf.predict_proba(X) for current_clf, X in zip(classifiers, x_list)])
pred2 = np.average(pred1, axis=0)
pred = np.argmax(pred2, axis=1)
label_encoder.inverse_transform(pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-cc7aa0181abb> in <module>()
#      11 pred2 = np.average(pred1, axis=0)
#      12 pred = np.argmax(pred2, axis=1)
# ---> 13 label_encoder.inverse_transform(pred)
#
# NameError: name 'label_encoder' is not defined
